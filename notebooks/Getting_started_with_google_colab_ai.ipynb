# %% [markdown]
# <a href="https://colab.research.google.com/github/eowilling/eoelior/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.5-flash', 'google/gemini-2.5-flash-lite']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.5-flash-lite')
print(response)
# Out:
# The capital of England is **London**.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Elara lived in Oakhaven, a town so old its history was etched into the cobblestones and whispered by the wind through the eaves of ancient houses. Its heart, both literally and figuratively, was the Great Clock Tower. For generations, its deep, sonorous chimes had marked the rhythm of daily life – waking the bakers, calling children home for supper, and signaling the end of long harvest days.
#
# Then, one Tuesday morning, silence. The sun rose, but no chime followed. The townspeople grumbled, nudged their pocket watches, and stared up at the silent, imposing structure. Engineers were called, but after a week of scratching heads and pronouncements of "too old," "too complex," and "beyond repair," the tower was deemed a lost cause. Oakhaven, for the first time in centuries, was timeless.
#
# Elara, however, felt a pang. She’d always loved the clock, tracing the intricate patterns on its face, imagining the whirring gears within. She saw it not as a broken machine, but a sleeping giant. One afternoon, armed with a dusty lantern and a stubborn spirit, she slipped past the rusted gate and into its shadowed base.
#
# The climb was long, the air thick with the scent of old wood and forgotten time. Dust motes danced in the lantern's beam as she ascended the spiral staircase, past enormous, silent bells and intricate networks of gears as tall as she was. Each step was a whisper from the past.
#
# Finally, she reached the main chamber, a cathedral of brass and steel, all frozen in motion. The massive pendulum hung still, a silent sentinel. Elara walked around, her fingers lightly tracing the cold metal, searching for any obvious fault. There was none – no snapped springs, no shattered cogs, nothing dramatic.
#
# She frowned, kneeling to inspect a particularly ornate section. And then she saw it. Not a broken part, but something entirely out of place. Tucked delicately between two crucial, interlocking gears, right where they were meant to meet, was a small, perfectly formed bird's nest, no bigger than her fist. A single, smooth, blue egg lay nestled within. A tiny, determined wren had found the quietest, most secure place in Oakhaven to raise its family, unwittingly halting the very heartbeat of the town.
#
# Elara smiled. With the utmost care, she gently scooped up the nest, setting it safely on a nearby ledge. She gave the gears a soft nudge. With a groan that seemed to resonate through the entire tower, the mechanism shuddered, then slowly, majestically, began to turn. The pendulum swung, a soft tick-tock filling the chamber.
#
# She scrambled down the stairs, heart pounding with a quiet triumph. As she emerged, blinking in the late afternoon sun, a deep, resonant *BONG* echoed through Oakhaven. Then another, and another, until the tower had chimed the correct time.
#
# Townspeople spilled from their houses, their faces a mixture of shock and joy. They looked at the tower, then at Elara, who simply smiled, a little dusty but utterly content. The engineers might have missed the grand solution, but Elara had simply seen the smallest detail. And sometimes, in a world of complexity, that was all it took to set things right.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.5-flash', stream=True):
  wrapper.print(chunk)
# Out:
# Ah, the Roman Empire! To speak of its evolution is to embark upon a journey
# through a millennium and more of human endeavor, ambition, triumph, and
# eventual, agonizing transformation. It is not a static entity, but a colossal,
# breathing organism, constantly adapting, growing, fracturing, and reconstituting
# itself across vast swathes of Europe, Africa, and Asia.
#
# Our saga begins not with an empire, nor even a republic, but with the humble,
# often brutal, origins of a small, fortified settlement on the Tiber River in the
# 8th century BCE. Legend, of course, speaks of Romulus and Remus, nursed by a
# she-wolf, but the historical reality points to a gradual coalescence of Latin
# tribes, strategically positioned at a crossroads of trade and fertile lands.
# Under a succession of legendary kings, both Latin and Etruscan, early Rome
# established the foundational institutions of its nascent state, building a city,
# fortifying its borders, and developing rudimentary social structures. This
# monarchical period, though shrouded in myth, laid the groundwork for the Roman
# character: pragmatic, martial, and fiercely independent.
#
# The yoke of monarchy, however, proved heavy, and around 509 BCE, a revolutionary
# fervor swept through the city, culminating in the expulsion of the tyrannical
# Lucius Tarquinius Superbus. Thus was born the **Roman Republic** – a grand
# experiment in self-governance that would last for nearly five centuries. The
# early Republic was a period of intense internal struggle, the legendary
# "Struggle of the Orders," between the aristocratic patricians and the common
# plebeians. Through strikes, secessions, and tireless political maneuvering, the
# plebeians gradually clawed their way to equality, securing rights, legal codes
# (like the Twelve Tables), and access to political office. This internal dynamic,
# while often turbulent, forged a remarkably resilient and adaptable political
# system of consuls, a powerful Senate, and popular assemblies, designed to
# provide checks and balances, though often prone to factionalism.
#
# Militarily, the Republic was a juggernaut. Starting with the conquest of the
# Italian peninsula, piece by painful piece, Rome developed the most formidable
# military machine of its age – the legendary legion. Its victories over the
# Samnites, Etruscans, and eventually the Greek cities of the South, cemented its
# dominance in Italy. But it was the **Punic Wars** against the mighty maritime
# empire of Carthage that truly transformed Rome into a Mediterranean power. These
# three epic struggles, particularly the second, where Hannibal Barca brought Rome
# to the brink of annihilation, tested Roman endurance, adaptability, and resolve
# to their absolute limits. Emerging victorious, Rome found itself master of the
# Mediterranean, inheriting vast new provinces and unimaginable wealth.
#
# This newfound power, however, sowed the seeds of the Republic's demise. The
# influx of wealth, slaves, and land led to ever-increasing disparities between
# the rich and poor. Small farmers, the backbone of the legions, were displaced by
# vast slave-run *latifundia*, swelling the ranks of the urban poor. Political
# corruption became endemic, and the traditional republican virtues of *pietas*
# (duty), *gravitas* (seriousness), and *virtus* (manliness/excellence) began to
# erode under the weight of ambition and greed. The late Republic descended into a
# century of civil strife, a ghastly procession of charismatic, ruthless generals
# vying for supreme power: Marius, Sulla, Pompey, Crassus, and ultimately, the
# incomparable Julius Caesar. Their private armies, loyal to their commanders
# rather than the state, shattered the illusion of republican consensus. Caesar's
# crossing of the Rubicon, his meteoric rise, and his brutal assassination marked
# the final, desperate gasp of the old order.
#
# Out of the ashes of this civil turmoil, through another round of bloody power
# struggles, emerged **Octavian**, Caesar's adopted son. With masterful political
# acumen, he skillfully navigated the treacherous currents of Roman society,
# establishing what would become known as the **Principate** – the first phase of
# the **Roman Empire**. Octavian, rebranded as **Augustus**, carefully veiled his
# absolute power behind a republican façade, presenting himself not as a king, but
# as *princeps* (first citizen). He consolidated his authority over the army, the
# provinces, and even religious affairs, bringing an end to nearly a century of
# civil war.
#
# This Augustan settlement ushered in the **Pax Romana** – two centuries of
# unparalleled peace, prosperity, and stability. Under the successive dynasties of
# the Julio-Claudians, Flavians, and the "Five Good Emperors" (Nerva, Trajan,
# Hadrian, Antoninus Pius, and Marcus Aurelius), the Empire reached its
# territorial zenith. Roman law, Latin language, and Roman culture spread across
# the vast dominion, uniting diverse peoples under a common administrative and
# economic system. Magnificent cities rose, connected by an unparalleled network
# of roads; aqueducts brought fresh water; and monumental architecture symbolized
# the Empire's might and sophistication. The sheer administrative genius required
# to govern such a colossal entity, from Britannia to Mesopotamia, is
# awe-inspiring.
#
# However, the very scale and success of the Empire contained the seeds of future
# challenges. The absence of a clear succession mechanism often plunged the state
# into crisis upon an emperor's death. The vast borders were an ever-present
# burden, requiring immense military expenditure to defend against increasingly
# aggressive "barbarian" tribes – Germanic peoples, Parthians, and later, the
# Sassanid Persians. Economic imbalances began to emerge, with resources flowing
# from the periphery to the core, and a growing dependence on slave labor stif
# ling innovation.
#
# The comfortable stability of the Pax Romana finally fractured in the **Crisis of
# the Third Century**. A dizzying succession of "barracks emperors," often lasting
# only months or years, vied for power, leading to incessant civil wars. External
# threats intensified, with Goths, Alemanni, and other Germanic tribes pouring
# across the weakened frontiers, while the Sassanid Persian Empire launched
# devastating attacks in the East. Economic collapse, rampant inflation, plague,
# and widespread depopulation pushed the Empire to the brink of total
# disintegration.
#
# It was from this nadir that the Empire was dramatically reshaped by a series of
# transformative emperors. **Diocletian** (284-305 CE) implemented radical
# reforms, dividing the Empire into East and West, establishing the "Tetrarchy"
# (rule by four) to improve administration and succession, and centralizing power
# into a more overtly authoritarian "Dominate." He tried to fix the economy
# through edicts and persecuted Christians, whom he saw as a destabilizing force.
# His successor, **Constantine the Great** (306-337 CE), cemented these changes,
# famously converting to Christianity (or at least legalizing and favoring it with
# the Edict of Milan), and establishing a new capital at **Constantinople** – New
# Rome – strategically located at the crossroads of Europe and Asia. These
# reforms, while restoring a semblance of order and stability, fundamentally
# altered the character of the Empire, making it more bureaucratic, militarized,
# Christian, and increasingly focused on its eastern half.
#
# The **Western Roman Empire** embarked on a protracted, agonizing decline in the
# 5th century. A perfect storm of factors converged: relentless pressure from
# migrating Germanic tribes (Visigoths, Vandals, Ostrogoths, Huns), a dwindling
# tax base to support its overstretched legions, political instability marked by
# weak emperors and powerful barbarian generals, internal social decay, and the
# psychological impact of repeated sacks of Rome itself (by the Visigoths in 410
# CE and the Vandals in 455 CE). The vast, interconnected system that had once
# been its strength became a brittle burden. Provinces peeled away, replaced by
# smaller, barbarian kingdoms. The idea of Rome persisted, but its centralized
# political and military authority in the West slowly, irrevocably dissolved. The
# traditional date of its "fall" – 476 CE, when the last Western Roman Emperor,
# Romulus Augustulus, was deposed by the Germanic chieftain Odoacer – is merely a
# convenient marker for a process that had been unfolding for decades, even
# centuries.
#
# Yet, the Roman Empire did not truly die. In the East, **Constantinople**
# endured, evolving into the **Byzantine Empire**. It preserved Roman law,
# administration, engineering, and the imperial tradition for another thousand
# years. While its language shifted to Greek and its culture became distinct,
# infused with Orthodox Christianity, Byzantium remained the legitimate heir to
# Rome, a radiant beacon of civilization amidst the "Dark Ages" of Western Europe.
# Its fall to the Ottoman Turks in 1453 CE marked the final chapter of this
# astonishing, unbroken lineage.
#
# The evolution of the Roman Empire is thus a majestic, sprawling narrative of
# continuous transformation. From a rudimentary village to a sophisticated
# Republic, then to a colossal Empire under the Principate, through an existential
# crisis, a radical re-imagining under the Dominate, and finally, a slow, complex
# dissolution in the West and a vibrant, enduring metamorphosis in the East. It is
# a testament to the enduring human capacity for organization, innovation,
# ambition, and resilience, a legacy that continues to shape our laws, languages,
# architectures, and political thought to this very day. Its story is not just
# history; it is a foundational pillar of Western civilization, a magnificent,
# "long-winded" epic etched into the very fabric of time.

# %%
# 安裝 Gradio 函式庫
# !pip install -q gradio

# %%
import gradio as gr
from google.colab import ai

# 定義一個函數來使用 google.colab.ai 進行文字生成
def generate_text_with_ai(prompt):
  try:
    response = ai.generate_text(prompt, model_name='google/gemini-2.5-flash')
    return response
  except Exception as e:
    return f"發生錯誤: {e}"

# 建立 Gradio 介面
iface = gr.Interface(
    fn=generate_text_with_ai,
    inputs=gr.Textbox(lines=2, placeholder="請輸入您的提示詞..."),
    outputs="text",
    title="Colab AI 文字生成器",
    description="使用 google.colab.ai 模型生成文字。"
)

# 啟動 Gradio 介面並獲取分享連結
print("正在啟動 Gradio 介面，請稍候獲取分享連結...")
iface.launch(share=True)
